# %%
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import pylab

# %%
df_mh = pd.read_csv('MillerHadenData.csv')
df_mh
# Out:
#     Participant  Abil   IQ  Home   TV
# 0             1    61  107   144  487
# 1             2    56  109   123  608
# 2             3    45   81   108  640
# 3             4    66  100   155  493
# 4             5    49   92   103  636
# 5             6    62  105   161  407
# 6             7    61   92   138  463
# 7             8    55  101   119  717
# 8             9    62  118   155  643
# 9            10    61   99   121  674
# 10           11    51  104    93  675
# 11           12    48  100   127  595
# 12           13    50   95    97  673
# 13           14    50   82   140  523
# 14           15    67  114   151  665
# 15           16    51   95   112  663
# 16           17    55   94   102  684
# 17           18    54  103   142  505
# 18           19    57   96   127  541
# 19           20    54  104   102  678
# 20           21    52   98   124  564
# 21           22    48  117    87  787
# 22           23    61  100   141  582
# 23           24    54  101   117  647
# 24           25    48   94   111  448

# %%
data = df_mh

# %%
data.head(5)
# Out:
#    Participant  Abil   IQ  Home   TV
# 0            1    61  107   144  487
# 1            2    56  109   123  608
# 2            3    45   81   108  640
# 3            4    66  100   155  493
# 4            5    49   92   103  636

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Participant'}>,
#         <AxesSubplot:title={'center':'Abil'}>],
#        [<AxesSubplot:title={'center':'IQ'}>,
#         <AxesSubplot:title={'center':'Home'}>],
#        [<AxesSubplot:title={'center':'TV'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data.describe()
# Out:
#        Participant       Abil          IQ        Home          TV
# count    25.000000  25.000000   25.000000   25.000000   25.000000
# mean     13.000000  55.120000  100.040000  124.000000  599.920000
# std       7.359801   6.084954    9.043782   21.039645   95.056965
# min       1.000000  45.000000   81.000000   87.000000  407.000000
# 25%       7.000000  50.000000   95.000000  108.000000  523.000000
# 50%      13.000000  54.000000  100.000000  123.000000  636.000000
# 75%      19.000000  61.000000  104.000000  141.000000  673.000000
# max      25.000000  67.000000  118.000000  161.000000  787.000000

# %%
#Based on previous analyses:
# 1A: 
# 1A: 
# 1A: 
# 1A:

# %%
data.plot.scatter(x='Abil',y='IQ')
# Out:
# <AxesSubplot:xlabel='Abil', ylabel='IQ'>

# %%
Abil = data['Abil']
IQ = data['IQ']

plt.scatter(Abil, IQ, c="r")
plt.xlabel("Abil") 
plt.ylabel("IQ")
plt.show()

# %%
plot_corr_sns = sns.regplot(x="Abil", y="IQ", color="r", data=data)
